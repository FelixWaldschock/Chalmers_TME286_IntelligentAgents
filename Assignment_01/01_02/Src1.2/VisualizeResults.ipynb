# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots

# use scienceplots style science
#plt.style.use(['science', 'no-latex'])
plt.style.use('science')

# %%
# load data
filePath = "/Users/felixwaldschock/Documents/gits/Chalmers_TME286_IntelligentAgents/Assignment_01/01_02/Src1.2/PerceptronClassifierSolution/PerceptronClassifierApplication/bin/Debug/AccuracyTracker.csv"

data = np.genfromtxt(filePath, delimiter=',', skip_header=1)

# create figure 400x400
plt.figure(figsize=(8,4))

# only look at the first 10000 epochs
data = data[:100]

# plot data
plt.plot(data[:,2], label="Training")
plt.plot(data[:,0], label="Validation")
plt.plot(data[:,1], label="Test")

plt.title("Accuracy of the perceptron classifier for the different datasets")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()
plt.show()

# save fig vectorial
plt.savefig('IA_1_1-2_Accuracy_Training_Testing.eps', format='eps')
